# %%
# !pip install yfinance "alpaca-trade-api==0.48" "alpha-vantage==2.3.1" --force-reinstall
# Out:
# ...
#   Using cached yfinance-0.2.65-py2.py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached alpaca_trade_api-0.48-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached alpha_vantage-2.3.1-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached asyncio_nats_client-0.11.5-py3-none-any.whl
# ...
#   Using cached pandas-2.3.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached urllib3-1.24.3-py2.py3-none-any.whl.metadata (36 kB)
# ...
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# ...
#   Using cached websockets-15.0.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# ...
#   Using cached Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached aiohttp-3.12.15-cp311-cp311-win_amd64.whl.metadata (7.9 kB)
# ...
#   Using cached numpy-2.3.2-cp311-cp311-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached multitasking-0.0.12-py3-none-any.whl
# ...
#   Using cached platformdirs-4.3.8-py3-none-any.whl.metadata (12 kB)
# ...

# %%
import sys
sys.path.append('../')

from src.data_fetch import fetch_yfinance
from src.preprocessing import create_features
from src.train_model import train_model

# --- Step 1: Fetch Raw Data ---
print("Fetching raw data...")
raw_data = fetch_yfinance("AAPL", period="2y", interval="1d")

# --- Step 2: Preprocess and Create Features ---
print("Creating features...")
featured_data = create_features(raw_data)

# --- Step 3: Train the Model ---
print("Training model...")
train_model(featured_data)

print("\nAll steps completed!")
# Out:
# Fetching raw data...
# c:\Users\saura\OneDrive\Desktop\project\notebooks\..\src\data_fetch.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period=period, interval=interval)
# [*********************100%***********************]  1 of 1 completed
# Creating features...
# Training model...
# Training on 384 samples, testing on 97 samples.
# Model Mean Squared Error on Test Data: 162.4780
# ✅ Model successfully trained and saved to c:\Users\saura\OneDrive\Desktop\project\notebooks\..\src\stock_model.pkl
#
# All steps completed!
# c:\Users\saura\OneDrive\Desktop\project\notebooks\..\src\preprocessing.py:31: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
